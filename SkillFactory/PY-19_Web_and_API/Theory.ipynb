# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url, verify=False) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cbr-xml-daily.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
print(response)
# Out:
# <Response [200]>

# %%
# Код ответа в виде числовой переменной можно получить с помощью метода status_code:
print(response.status_code)
# Out:
# 200

# %%
# Текст ответа хранится в атрибуте text
print(response.text)
# Out:
# {
#     "Date": "2023-04-05T11:30:00+03:00",
#     "PreviousDate": "2023-04-04T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2023\/04\/04\/daily_json.js",
#     "Timestamp": "2023-04-04T20:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 53.6845,
#             "Previous": 51.9388
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 46.6802,
#             "Previous": 45.8535
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
# ...

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран
# Out:
# {'Date': '2023-04-05T11:30:00+03:00',
#  'PreviousDate': '2023-04-04T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2023/04/04/daily_json.js',
#  'Timestamp': '2023-04-04T20:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 21.2244,
#                     'Value': 21.6071},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 20.0656,
#                     'Value': 20.4448},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
# ...

# %%
pprint(currencies['Valute']['EUR'])
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 84.6185,
#  'Value': 86.7207}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %%
import requests # Импортируем библиотеку requests
url_1 = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response_1 = requests.get(url_1, verify=False)  # Выполняем GET-запрос
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'nplus1.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'border-fw.retail.lenta.spb.rus'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
print(response_1.text)
# Out:
# <!-- IE friendly error message walkround.
#      if error message from server is less than
#      512 bytes IE v5+ will use its own error
#      message instead of the one returned by
#      server.                                 -->
#
#
#
#
#
#
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN">
# ...

# %%
from bs4 import BeautifulSoup

# %%
url_news = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response_news = requests.get(url_news, verify=False) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response_news.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'nplus1.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# Если при запросе к сайту, а затем при его разборе с помощью BeautifulSoup в тексте страницы не находится нужный тег, попробуйте вывести на печать пару тысяч символов текста страницы. Если там обнаружится нечто похожее на капчу, возможно, сайт посчитал вас роботом и отказывается выдавать содержимое. Чтобы получить его, попробуйте «притвориться» браузером при запросе из скрипта:
#
# ``` python
# requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
# ```
# User-Agent своего браузера можно узнать по этой [ссылке](https://whatmyuseragent.com/).

# %%
print(page.find('h1').text)
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
def wiki_header(url):
    response = requests.get(url, verify=False)
    page = BeautifulSoup(response.text, 'html.parser') 
    return page.find('h1').text

# %%
print(wiki_header('https://en.wikipedia.org/wiki/Operating_system'))
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Operating system

# %%
print(page.find('div', class_='n1_material text-18').text)
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %%
print(page.find('a', class_= "relative").text)
# Out:
# 11.10.21

# %% [markdown]
# Для ссылок в HTML предусмотрен тег <a> … </a>. Попробуем использовать find():

# %%
url_wiki = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response_wiki = requests.get(url_wiki, verify=False) # Делаем GET-запрос к ресурсу
page_wiki = BeautifulSoup(response_wiki.text, 'html.parser') # Создаём объект BeautifulSoup
print(page_wiki.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
links = page_wiki.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links))
# Out:
# 953

# %%
print([link.text for link in links[500:510]])
# Out:
# ['MAD', 'MAD/I', 'Magik', 'Magma', 'Máni', 'Maple', 'MAPPER', 'MARK-IV', 'Mary', 'MATLAB']

# %%
# Указываем свой сервисный токен
url_vk = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 'sorochina', 'v': 5.95, 'fields': 'sex, bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response_vk = requests.get(url_vk, params=params, verify=False) # Отправляем запрос
print(response_vk.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":8092167,"bdate":"23.9","sex":1,"first_name":"Евгения","last_name":"Копытько","can_access_closed":false,"is_closed":true}]}
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.vk.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
pprint(response_vk.json())
# Out:
# {'response': [{'bdate': '23.9',
#                'can_access_closed': False,
#                'first_name': 'Евгения',
#                'id': 8092167,
#                'is_closed': True,
#                'last_name': 'Копытько',
#                'sex': 1}]}

# %%
user = response_vk.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 23.9

# %%
print(user['first_name'])
# Out:
# Павел

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url_vk, verify=False, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}
# ...

# %%
ids_500 = ",".join(map(str, range(1, 501))) 
params = {'user_ids': ids_500, 'v': 5.95, 'fields': 'sex, bdate', 'access_token': token, 'lang': 'ru'}
resp = requests.get(url_vk, verify=False, params=params).json()
pprint(resp['response'])
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.vk.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [{'bdate': '10.10.1984',
#   'can_access_closed': True,
#   'first_name': 'Павел',
#   'id': 1,
#   'is_closed': False,
#   'last_name': 'Дуров',
#   'sex': 2},
#  {'bdate': '14.2',
#   'can_access_closed': False,
#   'first_name': 'Александра',
#   'id': 2,
#   'is_closed': True,
#   'last_name': 'Владимирова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 3,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 4,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
# ...

# %%
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. 
# Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
count_w = 0
count_m = 0
i = 0

for i in range(len(resp['response'])):
    if resp['response'][i]['sex'] == 1:
        count_w +=1
    elif resp['response'][i]['sex'] == 2:
        count_m +=1
    i +=1
share_w = round(count_w / (count_w + count_m), 2)
print(share_w)
# Out:
# 0.48

# %%
url_gr = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response_gr = requests.get(url_gr, verify=False, params = params) # Посылаем запрос
data = response_gr.json() # Ответ сохраняем в переменной data в формате словаря
pprint(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.vk.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'response': {'count': 13197322,
#               'items': [6,
#                         19,
#                         47,
#                         54,
#                         79,
#                         177,
#                         198,
#                         212,
#                         219,
#                         239,
#                         243,
#                         345,
#                         407,
#                         421,
#                         450,
#                         467,
#                         485,
#                         510,
#                         550,
#                         619,
# ...

# %%
print(len(data['response']['items']))
# Out:
# 1000

# %%
# Загружаем в переменную информацию об id первых 20 пользователей в виде списка
users_for_checking = data['response']['items'][:20]

# %% [markdown]
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import time
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params_gr = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    resp_gr = requests.get(url_gr, verify=False, params = params_gr) 
    data_gr = resp_gr.json() 
    user_ids += data_gr['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.vk.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Выгружаю 5 пользователей с offset = 5
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.vk.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Выгружаю 5 пользователей с offset = 10
# ...

# %%
users_for_checking == user_ids
# Out:
# True

# %%
url_wall = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params_wall = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response_wall = requests.get(url_wall, verify=False,params = params_wall) 
pprint(response_wall.json())
# Out:
# C:\Users\vadim.kopytko\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.vk.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'response': {'count': 590,
#               'items': [{'attachments': [{'photo': {'access_key': 'e1617c7078bff86eb4',
#                                                     'album_id': -7,
#                                                     'date': 1680614709,
#                                                     'id': 457341402,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1400252,
#                                                     'sizes': [{'height': 73,
#                                                                'type': 'm',
# ...

# %%
len(response_wall.json()['response']['items'])
# Out:
# 100

# %%
response_wall.json()['response']['items'][0]
# Out:
# {'comments': {'can_post': 1, 'count': 91, 'groups_can_post': True},
#  'marked_as_ads': 0,
#  'hash': 'k4PCzooUZg8SaUVzxQ',
#  'type': 'post',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1680614709,
#     'id': 457341402,
#     'owner_id': -22822305,
#     'access_key': 'e1617c7078bff86eb4',
#     'post_id': 1400252,
#     'sizes': [{'height': 73,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun4-8.userapi.com/impg/xyWU2DY93wIeodm1ERpVvLzIlPEpiJOdW1VM5A/bgZQQ3J-E_0.jpg?size=130x73&quality=96&sign=93cb679c6428aebc3b9e40c73bee4e9d&c_uniq_tag=1u7ZpbRTgYuTzMNtjzC7hAHhAUwgZszDtDcJzvtWt_s&type=album'},
#      {'height': 87,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun4-8.userapi.com/impg/xyWU2DY93wIeodm1ERpVvLzIlPEpiJOdW1VM5A/bgZQQ3J-E_0.jpg?size=130x87&quality=96&crop=153,0,1614,1080&sign=a482c50c399e02b60df8d58345b7c5fe&c_uniq_tag=Yp5zeWHTilbfeIpXNTTG-lMZ1F6N7K5EGvWPbWTUmWg&type=album'},
# ...

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response_wall.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'Content Day 2023 — уже сегодня': [133, 588, 165, 1679569702],
#  'В начале 2023 года мы запустил': [756, 1042, 246, 1678203000],
#  'Весна — время обновлений. Доба': [91, 320, 39, 1680687685],
#  'Главное событие для создателей': [201, 978, 201, 1679412660],
#  'Запускаем легендарную игру [ht': [228, 825, 441, 1680514467],
#  'К 8 Марта сотрудницы ВКонтакте': [3466, 3003, 461, 1678260600],
#  'Мы посвятим 3D-инсталляцию выд': [186, 938, 266, 1678192985],
#  'На Content Day 2023 поделились': [474, 881, 313, 1679651928],
#  'Сделайте свой профиль ещё крас': [727, 1354, 576, 1677758960],
#  'Сегодня День театра: отмечаем ': [861, 749, 128, 1679908456]}

# %%
import schedule
import time

# %%
def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(15).minutes.do(task)

while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\vadim.kopytko\Desktop\Learn\Project\SkillFactory\PY-19_Web_and_API\Theory.ipynb Cell 40 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/vadim.kopytko/Desktop/Learn/Project/SkillFactory/PY-19_Web_and_API/Theory.ipynb#X54sZmlsZQ%3D%3D?line=6'>7</a> while True:
#       <a href='vscode-notebook-cell:/c%3A/Users/vadim.kopytko/Desktop/Learn/Project/SkillFactory/PY-19_Web_and_API/Theory.ipynb#X54sZmlsZQ%3D%3D?line=7'>8</a>     schedule.run_pending()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vadim.kopytko/Desktop/Learn/Project/SkillFactory/PY-19_Web_and_API/Theory.ipynb#X54sZmlsZQ%3D%3D?line=8'>9</a>     time.sleep(1)
#
# KeyboardInterrupt:
